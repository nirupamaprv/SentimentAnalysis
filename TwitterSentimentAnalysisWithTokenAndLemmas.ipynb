# %% [markdown]
# ## Sentiment Analysis
# - learning about nltk packages using tutorials from Digital Ocean. References at bottom.

# %% [markdown]
# Steps to download nltk pakage and twitter samples
# ```
# import nltk
# nltk.download('twitter_samples')
# ```

# %%
import nltk
from nltk.corpus import twitter_samples

# %% [markdown]
# The strings() method of twitter_samples will print all of the tweets within a dataset as strings. Setting the different tweet collections as a variable will make processing and testing easier.

# %%
#create variables for positive_tweets, negative_tweets, and text:
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
# We also need the punkt module is a pre-trained model that helps you tokenize words and sentences
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nirupamaprv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# NLTK provides a default tokenizer for tweets with the .tokenized() method. 
# Add a line to create an object that tokenizes the positive_tweets.json dataset:
from nltk.corpus import twitter_samples

positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')

# %%
# to test the script to see the .tokenized method in action, add the highlighted content to your nlp_test.py script. 
# This will tokenize a single tweet from the positive_tweets.json dataset:
tweet_tokens1 = twitter_samples.tokenized('positive_tweets.json')[0]

# %%
print(tweet_tokens1[0])
# Out:
# #FollowFriday

# %%
print(tweet_tokens1[10])
# Out:
# my

# %%
print(tweet_tokens1)
# Out:
# ['#FollowFriday', '@France_Inte', '@PKuchly57', '@Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
print(tweet_tokens[3])
# Out:
# ['@97sides', 'CONGRATS', ':)']

# %%
print(tweet_tokens[10])
# Out:
# ['#FollowFriday', '@wncer1', '@Defense_gouv', 'for', 'being', 'top', 'influencers', 'in', 'my', 'community', 'this', 'week', ':)']

# %%
print(tweet_tokens[100])
# Out:
# ['@metalgear_jp', '@Kojima_Hideo', 'I', 'want', "you're", 'T-shirts', '!', 'They', 'are', 'so', 'cool', '!', ':D']

# %%
print(len(tweet_tokens))
# Out:
# 5000

# %%
print(tweet_tokens[1000])
# Out:
# ['@ArianeBeeston', 'Communal', 'knowledge', '!', ':)']

# %%
print(tweet_tokens[3500])
# Out:
# ['Shout', 'out', 'to', 'Grassy', ':-)']

# %%
# Repeating process for negative tweets:
tweet_tokens_n = twitter_samples.tokenized('negative_tweets.json')

# %%
print(tweet_tokens_n[3])
# Out:
# ['“', '@ketchBurning', ':', 'I', 'hate', 'Japanese', 'call', 'him', '"', 'bani', '"', ':(', ':(', '”', 'Me', 'too']

# %%
print(tweet_tokens[800])
# Out:
# ['@MsKristinKreuk', 'Hugs', 'ang', 'Kisses', 'from', 'the', 'philippines', ':)']

# %%
print(len(tweet_tokens))
# Out:
# 5000

# %%
print(tweet_tokens[4899])
# Out:
# ['we', 'just', 'face', 'timing', ':)', 'http://t.co/UoqAstlhxO']

# %%
# download library for lemmatization
# wordnet is a lexical database for the English language that helps the script determine the base word. 
# averaged_perceptron_tagger resource to determine the context of a word in a sentence.
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nirupamaprv/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nirupamaprv/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tag import pos_tag
from nltk.corpus import twitter_samples

tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %% [markdown]
# ##### From the list of tags, here is the list of the most common items and their meaning:
#
# - NNP: Noun, proper, singular
# - NN: Noun, common, singular or mass
# - IN: Preposition or conjunction, subordinating
# - VBG: Verb, gerund or present participle
# - VBN: Verb, past participle
#
#
# Full list at: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
tweet_tokens_n = twitter_samples.tokenized('negative_tweets.json')
print(pos_tag(tweet_tokens[0]))
# Out:
# [('#FollowFriday', 'JJ'), ('@France_Inte', 'NNP'), ('@PKuchly57', 'NNP'), ('@Milipol_Paris', 'NNP'), ('for', 'IN'), ('being', 'VBG'), ('top', 'JJ'), ('engaged', 'VBN'), ('members', 'NNS'), ('in', 'IN'), ('my', 'PRP$'), ('community', 'NN'), ('this', 'DT'), ('week', 'NN'), (':)', 'NN')]

# %%
print(pos_tag(tweet_tokens[3333]))
# Out:
# [('@NoakseyV1', 'JJ'), ('@david_statter', 'NNP'), ('@DHGFMadson', 'NNP'), ('@saikocat', 'NNP'), ('@HIDEO_KOJIMA_EN', 'NNP'), ('@drewdixon82', 'NNP'), ('@ghrowe', 'NNP'), ('Cheers', 'NNP'), ('!', '.'), (':)', 'NN')]

# %%
##### function that lemmatizes a sentence:


from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

#print(lemmatize_sentence(tweet_tokens[0]))

# %%
# remove noise from the dataset:

import re, string

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
# download library for stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nirupamaprv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# use the .words() method to get a list of stop words in English. 
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

print(remove_noise(tweet_tokens_n[0], stop_words))
# Out:
# ['hopeless', 'tmr', ':(']

# %%
print(remove_noise(tweet_tokens_n[1000], stop_words))
# Out:
# ['mean', 'offer', ':(']

# %%
positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
# compare tokens using this print statement
print(negative_tweet_tokens[500])
print(negative_cleaned_tokens_list[500])
# Out:
# ['Can', 'u', 'feel', 'it', '?', ':(', '(:', '(', '#exo', 'http://t.co/ghsa262ORm']
# ['u', 'feel', ':(', '(:', '#exo']

# %%
# following code defines a generator function named get_all_words
# this function takes a list of tweets as an argument to provide a list of words in all of the tweet tokens joined

def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)

# %%
#  find out which are the most common words using the FreqDist class of NLTK
#  we use the .most_common() method as it lists the words which occur most frequently in the data
from nltk import FreqDist
freq_dist_pos = FreqDist(all_pos_words)
print(freq_dist_pos.most_common(10))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253)]

# %%
#try with other list
all_neg_words = get_all_words(negative_cleaned_tokens_list)
freq_dist_neg = FreqDist(all_neg_words)
print(freq_dist_neg.most_common(20))
# Out:
# [(':(', 4585), (':-(', 501), ("i'm", 343), ('...', 332), ('get', 325), ('miss', 291), ('go', 275), ('please', 275), ('want', 246), ('like', 218), ('♛', 210), ('》', 210), ('u', 193), ("can't", 180), ('time', 160), ('follow', 156), ('sorry', 149), ('one', 149), ('see', 145), ('day', 144)]

# %%
# using the Naive Bayes classifier in NLTK to perform the modeling exercise
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
# prep training data and test data

import random

positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

# as the dataset is created by joining the positive and negative tweets.
# By default, the data contains all positive tweets followed by all negative tweets in sequence. 
# hence, to avoid bias, we opt to randomly arrange the data using the .shuffle() method of random.
random.shuffle(dataset)

# Since the number of tweets is 10000, we split as 7000:3000 for train:test sets 
train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
# printing to check if contains data
#print(train_data)
# Out:
# [({'aw': True, ':/': True, 'angeke': True, 'sbali': True, 'euuuwwww': True, 'lunch': True, 'like': True, 'real': True, 'construction': True, 'worker': True, ':-(': True}, 'Negative'), ({'ykr': True, 'sparky': True, '40mm': True, '3.5': True, 'grs': True, 'rockfishing': True, 'topwater': True, 'new': True, 'model': True, '2015': True, 'go': True, ':)': True}, 'Positive'), ({"i'm": True, 'get': True, 'super': True, 'slow': True, 'move': True, 'definitely': True, 'want': True, 'mono': True, 'life': True, 'remix': True, ':-)': True}, 'Positive'), ({'get': True, 'good': True, 'time': True, ':)': True}, 'Positive'), ({'promote': True, ':)': True}, 'Positive'), ({'time': True, 'need': True, 'bg': True, 'img': True, 'circle': True, 'crop': True, 'head': True, 'help': True, 'font': True, ':d': True, 'thanks': True}, 'Positive'), ({"ain't": True, 'gonna': True, 'follow': True, ':(': True}, 'Negative'), ({'forgot': True, 'ask': True, 'may': True, 'post': True, 'fb': True, 'happy': True, 'friday
# ...

# %%
# printing to check if contains data
print(train_data[5678])
# Out:
# ({'want': True, 'elevate': True, 'position': True, 'promotion': True, 'favor': True, 'god': True, 'men': True, '...': True, ':)': True}, 'Positive')

# %%
# using the .train() method to train the model 
# using the .accuracy() method to test the model on the testing data

from nltk import classify
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.9956666666666667
# Most Informative Features
#                       :) = True           Positi : Negati =   1679.5 : 1.0
#                 follower = True           Positi : Negati =     32.2 : 1.0
#                      sad = True           Negati : Positi =     23.7 : 1.0
#                      bam = True           Positi : Negati =     20.7 : 1.0
#                community = True           Positi : Negati =     15.9 : 1.0
#                      x15 = True           Negati : Positi =     15.4 : 1.0
#                  welcome = True           Positi : Negati =     15.0 : 1.0
#                     glad = True           Positi : Negati =     14.4 : 1.0
#                     sick = True           Negati : Positi =     13.2 : 1.0
#                      ugh = True           Negati : Positi =     12.8 : 1.0
# None

# %%
print(classifier.show_most_informative_features(25))
# Out:
# Most Informative Features
#                       :) = True           Positi : Negati =   1679.5 : 1.0
#                 follower = True           Positi : Negati =     32.2 : 1.0
#                      sad = True           Negati : Positi =     23.7 : 1.0
#                      bam = True           Positi : Negati =     20.7 : 1.0
#                community = True           Positi : Negati =     15.9 : 1.0
#                      x15 = True           Negati : Positi =     15.4 : 1.0
#                  welcome = True           Positi : Negati =     15.0 : 1.0
#                     glad = True           Positi : Negati =     14.4 : 1.0
#                     sick = True           Negati : Positi =     13.2 : 1.0
#                      ugh = True           Negati : Positi =     12.8 : 1.0
#                    didnt = True           Negati : Positi =     12.1 : 1.0
#                   arrive = True           Positi : Negati =     11.5 : 1.0
# ...

# %%
#check how the model performs on random tweets from Twitter.
from nltk.tokenize import word_tokenize

custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Negative

# %%
# tweet:  
# @WritesNiru and @Grammarly Thanks for the share! :)
custom_tweet2 = "@WritesNiru and @Grammarly Thanks for the share! :)"
custom_tokens2 = remove_noise(word_tokenize(custom_tweet2))

print(classifier.classify(dict([token, True] for token in custom_tokens2)))
# Out:
# Positive

# %%
custom_tweet3 = "When was the last time you felt truly heard?"
custom_tokens3 = remove_noise(word_tokenize(custom_tweet3))

print(classifier.classify(dict([token, True] for token in custom_tokens3)))
# Out:
# Negative

# %% [markdown]
# #### References:
# - [Digital Ocean](https://www.digitalocean.com/community/tutorials/how-to-perform-sentiment-analysis-in-python-3-using-the-natural-language-toolkit-nltk)
# - [Digital Ocean Ref2](https://www.digitalocean.com/community/tutorials/how-to-work-with-language-data-in-python-3-using-the-natural-language-toolkit-nltk)
